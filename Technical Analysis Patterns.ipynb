# %% [markdown]
# ### Flag Pattern

# %%
import mplfinance as mpf
import yfinance as yf

baba = yf.Ticker("BABA").history(start="2024-11-11", end="2025-02-07")[["Open","High","Low","Close","Volume"]]
mpf.plot(baba, type="candle", volume=True, title='BABA Daily Candlestick Chart')
baba.to_csv('./data/bullish/flag/baba.csv', index=False)

# %%
tem = yf.Ticker("TEM").history(start="2024-12-11", end="2025-01-30")[["Open","High","Low","Close","Volume"]]
mpf.plot(tem, type="candle", volume=True, title='TEM Daily Candlestick Chart')
tem.to_csv('./data/bullish/flag/tem.csv', index=False)

# %%
nflx = yf.Ticker("NFLX").history(start="2024-09-11", end="2024-11-06")[["Open","High","Low","Close","Volume"]]
mpf.plot(nflx, type="candle", volume=True, title='NFLX Daily Candlestick Chart')
nflx.to_csv('./data/bullish/flag/nflx.csv', index=False)

# %%
tsla = yf.Ticker("TSLA").history(start="2024-10-14", end="2024-12-05")[["Open","High","Low","Close","Volume"]]
mpf.plot(tsla, type="candle", volume=True, title='TSLA Daily Candlestick Chart')
tsla.to_csv('./data/bullish/flag/tsla.csv', index=False)

# %%
gme2024 = yf.Ticker("GME").history(start="2024-03-27", end="2024-05-09")[["Open","High","Low","Close","Volume"]]
mpf.plot(gme2024, type="candle", volume=True, title='GME Daily Candlestick Chart')
gme2024.to_csv('./data/bullish/flag/gme2024.csv', index=False)

# %%
gme2022 = yf.Ticker("GME").history(start="2020-11-18", end="2021-01-22")[["Open","High","Low","Close","Volume"]]
mpf.plot(gme2022, type="candle", volume=True, title='GME Daily Candlestick Chart')
gme2022.to_csv('./data/bullish/flag/gme2022.csv', index=False)

# %%
asan = yf.Ticker("ASAN").history(start="2024-10-02", end="2024-12-15")[["Open","High","Low","Close","Volume"]]
mpf.plot(asan, type="candle", volume=True, title='ASAN Daily Candlestick Chart')
asan.to_csv('./data/bullish/flag/asan.csv', index=False)

# %% [markdown]
# ### Base Pattern

# %%
app = yf.Ticker("APP").history(interval="1mo", start="2022-05-06", end="2024-02-08")[["Open","High","Low","Close","Volume"]]
mpf.plot(app, type="candle", volume=True, title='APP Monthly Candlestick Chart')
app.to_csv('./data/bullish/base/app.csv', index=False)

# %%
uber = yf.Ticker("UBER").history(interval="1mo", start="2021-10-08", end="2023-11-03")[["Open","High","Low","Close","Volume"]]
mpf.plot(uber, type="candle", volume=True, title='UBER Monthly Candlestick Chart')
uber.to_csv('./data/bullish/base/uber.csv', index=False)

# %%
googl = yf.Ticker("GOOGL").history(interval="1mo", start="2021-11-12", end="2024-03-28")[["Open","High","Low","Close","Volume"]]
mpf.plot(googl, type="candle", volume=True, title='GOOGL Monthly Candlestick Chart')
googl.to_csv('./data/bullish/base/googl.csv', index=False)

# %%
now = yf.Ticker("NOW").history(interval="1mo", start="2022-02-11", end="2023-11-10")[["Open","High","Low","Close","Volume"]]
mpf.plot(now, type="candle", volume=True, title='NOW Monthly Candlestick Chart')
now.to_csv('./data/bullish/base/now.csv', index=False)

# %%
pltr = yf.Ticker("PLTR").history(interval="1mo", start="2021-03-19", end="2024-08-17")[["Open","High","Low","Close","Volume"]]
mpf.plot(pltr, type="candle", volume=True, title='PLTR Monthly Candlestick Chart')
pltr.to_csv('./data/bullish/base/pltr.csv', index=False)

# %%
vst = yf.Ticker("VST").history(interval="1mo", start="2019-03-22", end="2023-07-14")[["Open","High","Low","Close","Volume"]]
mpf.plot(vst, type="candle", volume=True, title='VST Monthly Candlestick Chart')
vst.to_csv('./data/bullish/base/vst.csv', index=False)

# %%
hood = yf.Ticker("HOOD").history(start="2022-03-30", end="2024-02-26")[["Open","High","Low","Close","Volume"]]
mpf.plot(hood, type="candle", volume=True, title='HOOD Daily Candlestick Chart')
hood.to_csv('./data/bearish/base/hood.csv', index=False)

# %%
mndy = yf.Ticker("MNDY").history(start="2021-06-10", end="2021-08-13")[["Open","High","Low","Close","Volume"]]
mpf.plot(mndy, type="candle", volume=True, title='MNDY Daily Candlestick Chart')
mndy.to_csv('./data/bearish/base/mndy.csv', index=False)

# %%
alab = yf.Ticker("ALAB").history(start="2024-10-24", end="2025-02-21")[["Open","High","Low","Close","Volume"]]
mpf.plot(alab, type="candle", volume=True, title='ALAB Daily Candlestick Chart')
alab.to_csv('./data/bearish/base/alab.csv', index=False)
